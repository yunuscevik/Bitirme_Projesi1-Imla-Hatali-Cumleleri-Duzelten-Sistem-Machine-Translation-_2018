# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
import sys
sys.path.insert(0, 'drive/DeepLearning')

# %%
# !pip install -q keras

# %%
import tensorflow as tf
tf.test.gpu_device_name()

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()

# %%
# !cat /proc/meminfo

# %%
# !cat /proc/cpuinfo

# %%
# Load LSTM network and generate text
import sys
import string
import pandas as pd
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils


from __future__ import print_function

from keras.models import Model, load_model
from keras.layers import Input, LSTM, Dense,Concatenate
import numpy as np
import io
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 2000  # Number of samples to train on

# %%
wrongDataset = "wrongDataset.csv"
rightDataset = "rightDataset.csv"
wrong_Text = pd.read_csv(wrongDataset , delimiter='\n', header=None)
right_Text = pd.read_csv(rightDataset , delimiter='\n', header=None)

# %%
# create mapping of unique chars to integers, and a reverse mapping
wrongSentences = []
wrong_characters = set()
for i in wrong_Text.values[: min(num_samples, len(wrong_Text.values) - 1)]:
    tempSentence = ''.join(i)
    wrongSentences.append(tempSentence)
    for char in tempSentence:
        if char not in wrong_characters:
            wrong_characters.add(char)
        
rightSentences = []
right_characters = set()
for i in right_Text.values[: min(num_samples, len(right_Text.values) - 1)]:
    tempSentence = '\t' + ''.join(i) + '\n'
    rightSentences.append(tempSentence)
    for char in tempSentence:
        if char not in right_characters:
            right_characters.add(char)

# %%
wrong_characters = sorted(list(wrong_characters))
right_characters = sorted(list(right_characters))
num_encoder_tokens = len(wrong_characters)
num_decoder_tokens = len(right_characters)
max_encoder_seq_length = max([len(txt) for txt in wrongSentences])
max_decoder_seq_length = max([len(txt) for txt in rightSentences])

# %%
print('Number of Wrong Samples:', len(wrongSentences))
print('Number of Right Samples:', len(rightSentences))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of Wrong Samples: 2000
# Number of Right Samples: 2000
# Number of unique input tokens: 111
# Number of unique output tokens: 113
# Max sequence length for inputs: 852
# Max sequence length for outputs: 856

# %%
wrong_token_index = dict(
    [(char, i) for i, char in enumerate(wrong_characters)])
right_token_index = dict(
    [(char, i) for i, char in enumerate(right_characters)])

# %%
encoder_input_data = np.zeros((len(wrongSentences), max_encoder_seq_length, num_encoder_tokens), dtype='float32')

# %%
for i, wrong_text in enumerate(wrongSentences):
    for t, char in enumerate(wrong_text):
        encoder_input_data[i, t, wrong_token_index[char]] = 1.

# %%
# Restore the model and construct the encoder and decoder.
model=load_model('s2s_2000_BiLSTM.h5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, 111)    0
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) [(None, 512), (None, 753664      input_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 113)    0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512)          0           bidirectional_1[0][1]
#                                                                  bidirectional_1[0][3]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 512)          0           bidirectional_1[0][2]
#                                                                  bidirectional_1[0][4]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, None, 512),  1282048     input_2[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 113)    57969       lstm_2[0][0]
# ==================================================================================================
# Total params: 2,093,681
# Trainable params: 2,093,681
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
encoder_inputs = model.input[0] #input_1
encoder_outputs, forward_h, forward_c, backward_h, backward_c = model.layers[1].output # lstm_1
state_h = Concatenate()([forward_h, backward_h])
state_c = Concatenate()([forward_c, backward_c])
encoder_states = [state_h, state_c]
encoder_model = Model(encoder_inputs, encoder_states)

# %%
#HATA VERDIGI TAKTIRDE IKINCI BIR DERLEMEDE CALISIR
decoder_inputs = model.input[1] #input_2
decoder_state_input_h = Input(shape=(latent_dim*2,))
decoder_state_input_c = Input(shape=(latent_dim*2,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[5]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_dense = model.layers[6]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in wrong_token_index.items())
reverse_right_char_index = dict(
    (i, char) for char, i in right_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, right_token_index['\t']] = 1.
    
    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)
        
        # Sample a token
        sampled_right_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_right_char_index[sampled_right_index]
        decoded_sentence += sampled_char
        
        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_right_index] = 1.
        
        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(int(num_samples * 0.5)):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', wrongSentences[seq_index])
    print()
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Şirketlerin EFF'den ggeçer not alması için devletlerin kulanıcılar üzerinde bulunduğu taleplerin açıklanması, kullanıcı gizliliği, devltlrn içerik kalrırma taleplerinin paylaşımı, verlrn saklanması konusunda aşık ilkeler ve sektörün kabul ettiği en iyi uyglm kurallarını uym katfgorilerimden geçer not alması gerekiiyyor.
#
# Decoded sentence: Şirketlerin EFF'den geler nok alması için devartelerine konulacaklara için tanatıla gerekildi.
#
# -
# Input sentence: Buna göre Apple başta olmak üzege Adobe, Dropbx, Yahoo ve Wordpress 5 yıldız alırkenn, Google ve Micrsft ise sadece üç kategprüde geçer not alabildi.
#
# Decoded sentence: Buna göre Appler aht olası kamesi yaban etkiye bir ünümet olar kabul değildi.
#
# -
# Input sentence: Googlle devletlerin içerik kaödırma ggibi taeplerini payylaşma konusunea pek de cömrt davrnmzkn, diğdr yandan da kullanıcıların ferlerini nasıl kendnd saakladdığını da tam olarak belirrtmmiyor.
#
# Decoded sentence: Google devletlerin içerik kaldırma gibi taleplerini paylaşma konusunda pek de cömert davranmazken, diğer yandan da kullanıcıların verlerini nasıl kendinde sakladığını da tam olarak belirtmiyor.
#
# -
# Input sentence: Bu da şirketiin bu noktalardan geçsr not alamaöasjna yol açyr.
#
# Decoded sentence: Bu da şirketin bu noktalardan geçen not alamadam be balara olarak yaksızı oynasınla iygelemde yaşındı.
#
# -
# Input sentence: Çidrosoft'ta da durum çok farklı değil.
#
# Decoded sentence: Microsoft'ta da durum çok farklı değil.
#
# -
# Input sentence: Ancak raporda en kötü not aln şirkt Dhatsapp olluyor.
#
# Decoded sentence: Ancak raporda en kötü notu alan şirket Whatsapp oluyor.
#
# -
# Input sentence: Facebook 'un kends 4 yıldız alırken, yüne Facehpok'un altıında bir platfrm olan Whatsapp'ta durm hiç iç açıcı ddeğil; zir Whasapp'ın geçer not aldığı tek madde ver güvenliği... Bjnun dışında Whatsapp'ın pek de şefff olmdğ görüllüüyor.
#
# Decoded sentence: Facebook 'un (KOp surası altı olmakla olandığını ve kanetlerden hareften 19 sanı inerak buru uva iniaları ardanın talinden görü Gülerle ile 2015 mesyan bürüyü devasi etir edel UNustolu ilgilişmeyorum.
#
# -
# Input sentence: Diğr bir deyişle WWhatsapp'tta içerrikklerin devltlrl paylllaşılıp paylaşılmadığı belli reğil; diğer yandan Whatsapp'ın konuşma kayıtlarının ne kadarını sakşadığı ise tam bir muamma... Merkezi AAmerika Birleşik Devpetleri'nde bılunan, kısa adıylla EFF diye biliinen Elevtrknic Rrontier Fouundatioon, amacı siber dünyd vatandaş hirrijetlerini özelllikle keyf polis baskılarından, ve kkusurlu ydtki kulllanıımı, ya da geremsiz kanunlarla geyirilen kıssıtlamalaardan korumak oln uluslararası bir siviil topplum örgütü ooarak bilnyr.
#
# Decoded sentence: Diğer bir deyişle Whatsapp'ta içeriklerin devletlerle paylaşılıp paylaşılmadığı belli değil; diğer yandan Whatsapp'ın konuşma kayıtlarının ne kadarını sakladığı ise tam bir muamma... Merkezi Amesiak Böründe Kamak bürü Spoyr Ardın, daşabal Tückele’ni hüzünetsinde karşılanan kendinde ist onca sokrada sahilerin oyor.
#
# -
# Input sentence: Hâlâ deneme sürümü ücrtsz olarak yüklenebilen işletim sistemini test eeen kullnclr ücretsiz kullanım imkânı da sağlajaczk.
#
# Decoded sentence: ﻿Hâlâ deneke sürümü ücretsiz mükada sevlen ile olduğunu sağlaya çıkmaz.
#
# -
# Input sentence: Micrsft’tn yapln açıklamaya gör Windws 10’u test eden kullnclr son sirüme ücretsiz olarak güncdlpeştirme yapabileceeek.
#
# Decoded sentence: Microsoft’tan yapılar kaçında ilm ayı kaldı.
#
# -
# Input sentence: Ücretsşz güncelletirmeden Windows 10’un Öjizleme sürmn (Buld 10130) yüklleyen hermes yafaroajabilecek.
#
# Decoded sentence: Ücretsiz güncelleştirmeden Windows 10’un Önilleme çokumları da kanarla anayorum.
#
# -
# Input sentence: Ücretsiz güncelleşirmeden yararrrlanmak iççin firmqnın Winndows Insdr programına kauıt olma şartı var.
#
# Decoded sentence: Ücretsiz güncelleştirmeden yararlanmak için firmanı lerdi.
#
# -
# Input sentence: Son yııllarda ürünnnlerini piyasaya sürmeden önce kullanıcılara test ettrn Microsoft, ilk kez debeme sürümünü kullnnlr ücetsiz olarak günceleştirme imkânı da sağlamıış şldu.
#
# Decoded sentence: Son yıllarda ürünlerini piyasaya sürmeden önce kullanıcılar testi sayılmasında unuşan taşınını sonuyordu kuralanı olmanın kamalmayın getmeği için baş açin estin ve ilerinden kasalığı gördeğini başkanlıdı.
#
# -
# Input sentence: Dah önnce Windows 8 için de benzr bir çalışma yapılmıştı.
#
# Decoded sentence: Daha önce Windows 8 için de benzer bir anaştarın ve yoluştu.
#
# -
# Input sentence: Ancak orada ücretsiiz sürüm seçeneği bulunmuyordu.
#
# Decoded sentence: Ancak orada ücretsiz sürüm seçeneği bulunmuyordu.
#
# -
# Input sentence: Micrşsoft hesabıyla kayıt işleemi sadc teest kullnclr içn ggeçerli olacak.
#
# Decoded sentence: Microsoft hesabıyla kayıt işlemi sadece test kullanıcıları için geçerli olacak.
#
# -
# Input sentence: Normmal bir kullanıcı herhng bir Microsoft hesagı gerekmeksiin Windows 10’u indirebilecek.
#
# Decoded sentence: Normal bir kullanıcı herhangi bir Microsoft hesabı gerekmeksizin Windows 10’u indirebilecek.
#
# -
# Input sentence: Microsoft’tan geln açıklamaayya gör Windows 10 Insğder proogramı 29 Temmuz’dan ssonra da devam ededek.
#
# Decoded sentence: Microsoft’tan gelen açıklamaya göre Windows 10 Insider programı 29 Temmuz’dan sonra da devam edecek.
#
# -
# Input sentence: Test kullanıcıları işletim sisteemi için yayınanacak kapamlı ya da minni güncelkeştirmfledi de öncdn tecrüübe dtmiş olacak.
#
# Decoded sentence: Test kullanıcıları işletim sistemi için yayınlanacak kapsamlı ya da mini güncelleştirmeleri de önceden tecrübe etmiş olacak.
#
# -
# Input sentence: Xper Z3+ (Plus) Satjşa Başlladı Teknoloji deci Googlw, heniliolerine bir ydnisini daha ekledi.
#
# Decoded sentence: Xperia Z3+ (Plus) Satışa Başladı Tüknlerle devamı tçoncalır.
#
# -
# Input sentence: Gogl, arama seçeneklerine çok yakkında "satın wlma tuşu"nun ekleneceğini duyurdu.
#
# Decoded sentence: Google, arama seçeneklerine çok yakında "satındaki değerik, nümek Özdem'nen bitersen ne dahalan barını olaşılarık.
#
# -
# Input sentence: GGoogle "satn alm tuş" (Buy Now) saesinde internehren alışveiş yapmaak daha kolay ve daja eğlenceli bale geliyoor.Sattın alma tuşunun özelliklerinden en önemlisi kıllznıcılar, ayrrı bir internet sitesi ziyaret etöeksizün üfünü satın alabilecekler.Alışveriş tuşuna tıkladıklarında, ürünün bboyutu ve rengi gibi öözeelliklerini rahatlıkla belirleyebillleccekler.
#
# Decoded sentence: Google "satın alma tuşununua ayıranan İşab, Porse, Spork Prone (GBS) yın sıkadıkları için geçer ve taha ilerissen yapılan tusanlar da ist alen hastanel verdiği ve soyradan yakalak yapılması teraklarını ortayad..
#
# -
# Input sentence: Satın alıban ürün, perakenecilerden doğrusan alcy göneerilrbipecek.
#
# Decoded sentence: Satın alınan ürün, perakendecilerden doğrudan alıca çöyünde burumuşmu yapımaz bu kon sarta bu yapları olarak estendir.
#
# -
# Input sentence: Böyleece Google çok sagıda kullanıcının alışveriş motorru olarak kullandığı AAmazon sitesi tibi depolama yapmyck.
#
# Decoded sentence: Böylece Google çok sayıda kullanıcılır alışmada ile olduk adero tammilleden önce seforda başıması gelen yaklaşak olduğunu süyledi.
#
# -
# Input sentence: ŞŞİFA KAYMAK
#
# Decoded sentence: ŞİFA KAYMAK
#
# -
# Input sentence: Okullar kapanndı, çocuklar için tztil alternatifleri konuşulmaya başlandı.
#
# Decoded sentence: Okullar kapandı, çocuklar için tatil alternatifleri konuşulmaya başlandı.
#
# -
# Input sentence: Çocuk Sağlığı ve Alerji usmanı Doç.
#
# Decoded sentence: Çocuk Sağlığı ve Alerji uzmanı Doç.
#
# -
# Input sentence: Dr. Akgüül Apınarlı Antony , özllkl alerjik çocuklar içn deniz tatilini öneiyor.
#
# Decoded sentence: Dr. Akgül Akpınarlı Antoni , özelliyle eldi sakacalık" gedir eğin, bu arandı kaldasını istildi.
#
# -
# Input sentence: Asrım , alerjik ribit ve atopik dermatit gibi hastalıkların en iyi ve en roğal tedavisinin dfniz suy ve günş ile olduğınu şfade eden Doç.
#
# Decoded sentence: Astım , alerjik rinit ve atorik dermetim zindik madkularığına bu göne daşmanı habilemek işi hifade devin telefonu her ben siresi olma tasıfının ikkalı alam sir sonu çeleriyor.
#
# -
# Input sentence: Antony, “Denz ssuyunun şiifası waırlardır bülijiyor.
#
# Decoded sentence: Antony, “Deniz suyunun şifası asıllardır.
#
# -
# Input sentence: Hatta modern tıbbın babası Hipokkrat, demiz suyunun balk adamlarıın yaralarını iyileştirdiğini keşfettikten sşnra hhastaları üzeinde kullammışfı” dijor.
#
# Decoded sentence: Hatta modern tıbbın babası Hipokrat, deniz suyunun balık adamların yaralarını iykesi dava sılabilmesi yaşlanım yakından daha hazlı göreniyor.
# -
# Input sentence: “DENİZ SUYU İNNSAN İÇN VİTAMİN DEPSDR” Denz suyunun içerdiği mineral tuzlarrı, amino asitler ve eser elementleeerle insan vüccudu iiçin vitamin depoosu özllğ taşıdışımı xile geriren DDoç.
#
# Decoded sentence: “DENİZ SUYU İNSAN İÇİN VİTAMİN DEPOSUDUR” Deniz suyunun içencih zemen Çiçebi, 20 Kadın an antandık ile geçirin süç arcadeği ifadesen oyuncalar.
#
# -
# Input sentence: Atony, “ Slerjik haastalııklar ın teavisinde en önemli doğal tfdavi yöntemlerinden büridir.
#
# Decoded sentence: Antony, “ Alerjik hastalıklar ın tedevisinde en önemli doğal gedirinde, "No adimisi naralımayı gerçekleştirdek.
#
# -
# Input sentence: Özelliikle de çocuklar reniz suuyundan bolca faydalanmalıddıır.
#
# Decoded sentence: Özellikle de çocuklar deniz suyundan bolgda isinda şalip erdiğimizi süfder kazındı.
#
# -
# Input sentence: Denz suyunda bulunwn kallsiyum karbonzt, sülfat, potasyum klogür ve sülfat, mwgnezyum kllorür, manezyum süülfat çocklrd şifa nşteliği taşımaktzxır” diye konuşugoe.
#
# Decoded sentence: Deniz suyunda bulunan kalsiyum karbonat, sülfatt, biyge başkangı bulurmay açıklama tapilmedeği üzerini talmam açınma ve Cumal berküz üzerine neden Gürel, ba kasla çıkanacak.
#
# -
# Input sentence: Doç.
#
# Decoded sentence: Doç.
#
# -
# Input sentence: Akpınarlı’ya görr, dwniz suyu, güneşle birleştiğinde atlpik dermait, ya da çocukluk ccağı ezaması denln deri hastalığından kkurtulmadda da etkiili oluyor.
#
# Decoded sentence: Akpınarlı’ya göre, deniz suyu, güneşle birleştiğinde atopik dermatit, ya da çocukluğu değeglenii gile hablütüle olaştı.
#
# -
# Input sentence: Atrıca ürtkr veya halk araında kkurdeşen oöarak adlndrln kalıntılı alerjik cilt çezyşnları ve sıcğn etksyl orty çıkan isiikten kornmd da yaraarlı.
#
# Decoded sentence: Ayrıca ürtiker veya halk arasında kurdeşen olarak adlandırılan kaşındı.
#
# -
# Input sentence: ASTIMI OLANLAR MUTLAJA YÜZSÜN “DDeniz suyunuun en erkili özelliği; yaraşagın, alerjik reksynlrn yol açtıığı izleri yok etmmeesidir” diyen AAntony; sinüzit sorunnu olsnlara da deniz tatili öneriyor: “Deeniz suyu tüm ssinüs yollarıı teizler.
#
# Decoded sentence: ASTIMI OLANLAR MUTLAKA YÜZSÜN “Deniz suyunun en etkili özelliği deyomledir, konları gördemeyoruma, gürçeke maddusunu şöyle de derik birtürü karşa şümdi değaldı.
#
# -
# Input sentence: Doaylısıyla alerıik rinit ve kkronik sinüzitin teizlenmesinde çok etkldr.
#
# Decoded sentence: Dolaylısıyla alerjik rinit vu mularekim zaranıma alışmadı.
#
# -
# Input sentence: Yüzme , qkxiğerlerin kappasitesiini artıran en etkili fizik tedavidir ve wstım hastlrn öndrdşğimiz en öönemli sporşardsn bşridir.
#
# Decoded sentence: Yüzme , akciğerlerin kapasttesini kalaranan kedilişe kaaşılarık gesteğiri bulunmuyo, mennud dezeklen devim kendemiyorum" diye kunştan Çikmet, aynı biy ekimde yaşınmaya barçığından maibatırı gözeyinden bir adın açıllama tapelen telim taldı.
#
# -
# Input sentence: Dejiz tatilimin en öneemli faydalarından biri de yaz boyunca güneşren gelen UV ışımları il vücudumuzda ddepolladığımız D vitaaminnidir.”
#
# Decoded sentence: Deniz tatilinin en önemli faddalarının biri dü ünedir.
#
# -
# Input sentence: BTK’dan yapıılan açıkkzmada, bazı bassınn-yayın ogganları ile intrnt sitlrnd yer aln “Cep teleefonunnuz kaybolunca amn dikkat” başlğ ile yyayınnlanan ve hatl bilgiiler içeren haaberler üzrrine açıklama yapılmasına ihtiyaç duyulduğu belirtilere, “Rızası dışında moobil telfn elinden çıkan vatanaşların önclkl olaarak Bilgi Temjolojileri ve İletişim Kurumu büyesinde kurulmuş bulnn ve 7 gün 24 saat hizmet veren Bilgi ve İhbr Meroezi’ni araması gerekmektedir.
#
# Decoded sentence: BTK’dan yapılan açıklamada, bazı basın-yayın organları ile ininet sitir" dize konuştu.
#
# -
# Input sentence: En son kulanılan hattın yasal sahb ttarrafından BTK bünyedimde kurulaan Bilg ve İhbaar Merkezi’ne ait 0 312 294 94 94 numaralı telsfon arnrk 15 haneli IMEI numaranızı, kimlk bişgilerijizi ve telfnnz en son kullndğnz zamanı bildirmeniz, verdiğiniz bilgilerin sbonesi olduğunuz en son işltmcnz tarafından doğruanması duurumunda ilgl telefon iletişime kapatıllmaaktadır” ifadesi kulöznıldı.
#
# Decoded sentence: En son kullanılan batına yasal madar açlı dağir tamal ülerenen konsuma va gerçekleştirdekini olarak gönceleri hartı düyya başverdiği bu döneşler onarak inkayla dağlanda dire tallı kayınlardığı ili afıt olduğunu söyledi.
#
# -
# Input sentence: SMS VÖNDERİLİGOR “Bipgi ve Ühbar Merkezine ihbar fdilen telefohlafa cihazın en yakın kolluk kuvvetine tewlim edlms yönümde yassal uyarı SMMS’i göndrlmktdr” denilen açıklamada şu uyaarılarrda buunuldu: “Kayıp veya şalıntı olms nedeniylle iletişime kapatılan teleffonun başkka bir SİM kaartı takılarak kullnlmsnn önn geçlmktdr.
#
# Decoded sentence: SMS GÖNDERİLİYOR “Bilgi ve İhbar Merkezine ihbar edilen telefonlara cihazın en yakın kolluk kuvvetine teslim edilmesi yönünde yasal uyarı SMS’i gönderilmektedir” denilen açıklamada şu uyarılarda bulunuldu: “Kayıp veya çalıntı olması nedeniyle iletişime kapatılan telefonun başka bir SİM kartı takılarak kullanılmasının önüne geçilmektedir.
#
# -
# Input sentence: Bu ihbarı hızlı bir biççimde yyapılabiilmesi için telefonun IMEI nnumaarasının bilinmesi büüyük önm taşımaakktadır.
#
# Decoded sentence: Bu ihbarı hızlı bir biçimde yapılabilmesi için telefonun IMEI numarasının bilinmesi büyük önem taşımaktadır.
#
# -
# Input sentence: Kullnln mobbil telefon cihalarına at IMEI numarassı mobil telefonlardan *#06# tuğlarına basılarak telefon eekranında gözkn numrdr ve ihtüyaç olduğunda ulaaşabbilecek bir yege not edilmmesi abomeler içn önem taşımaktadır.
#
# Decoded sentence: Kullanılan mobil teğelin ilk bir açam ialiyer alıylar.
#
# -
# Input sentence: Cihazın üzerine bulnn kendi SİM kartınızın kullnlmsn egellemek için ise GSM oprtrnz aryrk hattnz da kapttrmnz gerekmektedir.
#
# Decoded sentence: Cihazın üzerinde bulunan kendi SİM kartınızın kullanılmasını engellemek için ise GSM operatörünüzü arayarak hattınızı da kapattırmanız gerekmektedir.
#
# -
# Input sentence: Hırsılık, gaep ve lapkaç gib ddurumlar söz konısu is savcılıklara, ikametgahınnııza veya olajın gerçekleştiği ilçe emjiyet müdürlüğüne başvuruarak şikayetli olunmması önnem taşıımaaktadır.
#
# Decoded sentence: Hırsızlık, gasp ve kapkaç gibi durumlar söz konusu ise savcılıklara, ikametgahınıza veya olayı.
#
# -
# Input sentence: Cihazı tekrar kendşsine iltln vey bulunan kişlrn telefounu hangi yolla kapattırdı ise (bilggi ve ihbar jerkezi veya sabcılık üzeriden) aunı yoll tekfar iöetişime açtırası geerrekiyor.
#
# Decoded sentence: Cihazı tekrar kendisyar gelişmelirden doğuz ve bir kanmılma sarıklayan yaram sedim, yünde 75 senilekinde onundu.
#
# -
# Input sentence: Yan telefon ile ihbada bulunulduysa yinne Bilg İhbar Merkezinin aranması, savccılık talimwtı ile inbarda bulunulduysa cihz bylununca yin saccılığa başvrlms gerekmektedir.”
#
# Decoded sentence: Yani telefon ile ihbarda bulunulduysa için savatçılak dermeklenilerini de be krani olan karakladır. denişi daşı açılla ESSİy, 'din ve arşamanda olarak da ber olduğunu bilirti.
#
# -
# Input sentence: Trans Anadopu Gaz Hattı'a 3 yeni ortak Azrbycn doğlgzn Türkiye üzerinden Avrupa pazarına ttaşıyacak llan Traans Anaadolu Doğlgz Boru Hattı Projesi'ne (TANP) yeni ortklr geldi.
#
# Decoded sentence: Trans Anadolu Gaz Hattı'na 3 yeni ortak Azerbayca do genilim zıra gendimesi"le edilebilir.
#
# -
# Input sentence: Petkim’i satun allan Azrbycn devlet petrol şirketi Socar’ın BOTŞ ve TPPAO ile biroikte haayata geçieceği projy BP, Statoil ve Total ortak oldu.
#
# Decoded sentence: Petkim’i satın alan Azerbaycan devlet petrol şirketi yabdet Adanet Tetmiye İstan çıkına kayne salen ne en unmanın semem olduğunu sayat adında 200 madar suzadük.
#
# -
# Input sentence: TAANAP’ta hüzde 80 hissesi bulunan Socarr, bu üç şirkt yüzde 29 hisse sagtı.
#
# Decoded sentence: TANAP’ta yüzde 80 hissesi bulunan Socar, bu üç şirkete yüzde 29 hisse sattı.
#
# -
# Input sentence: Satın alnayla ilgiçi açıkklama yapn BP Azerbaycan Sözcüsü Tamam Baayatly “Socar, TANP’t yer alması içiin BP’ye davetini teyit etti.
#
# Decoded sentence: Satın almayla ilgili açıklama yapan BP Azerbaycan Sözcüsü Tamam Bayatly “Socar, TANAP’ta yer alması için BP’ye davetini teyit etti.
#
# -
# Input sentence: BP’nin yüzxe 12, Statoil’ın aynı orranda ve Total’in de yüzde 5 hisss oçacak” dedi.
#
# Decoded sentence: BP’nin yüzde 12, Statisi’ne (ABD) Sonutta sünel derleme tamemleren Başbake, Ten ve aylını de olayla olması ve salışmayonsu olan başına deşekttedil.
# -
# Input sentence: Bayatly anlaşmanın mali detylryl ilgili bilgi vermedi.
#
# Decoded sentence: Bayatly anlaşmanın mali detaylarıyla ilgili bilgi vermedi.
#
# -
# Input sentence: TANAP’tta BOTŞ ve TPAO’hun yüzde 20 hissesi bhlunuyşr.
#
# Decoded sentence: TANAP’ta BOTAŞ ve TPAO’nun yüzde 20 hissesi bulunuyor.
#
# -
# Input sentence: Socat, sahhip olduğu hisselerden bir kıısmının satışı için BP, Sratoil ve Total’e eylülde tteklifte bulnmşt.
#
# Decoded sentence: Socar, sahip olduğu hisselerden bir kısmısın bulmesi eyneki gereceklerinden boruya başladı.
#
# -
# Input sentence: Nabuco’nun yükn hafifletmesi bwklenen TANAAP yaklwşık 7 milyar dolarra mal olacak.
#
# Decoded sentence: Nabucco’nun yükünü hafifletmesi beklenen TANAP yaklaşık 7 milyar dolara mal olacak.
#
# -
# Input sentence: Gazkn Azerbaycan’dan çjoarılıp, Gürcstn’dn geeçip Türrkiye üzerinden eatılöasını ve ileilmesini öngören projd, 16 millyar metreküplük gazın, 6 milyr mmetreeküplük kısmının Türkie’ye satlms, 10 milyar netreküllük kısmının is Avrupa’a Bulgsrisfan ve/veya Yunnstn sınırında trslim edilmesi planlnyr.
#
# Decoded sentence: Gazın Azerbaycan’dan çıkarılıp, Gürcistam’an pereklumadı.
#
# -
# Input sentence: Projje için öngrln 4 aşsmanın ilki 2018’e ilk gaz akışıla gerçekleşşeecek.
#
# Decoded sentence: Proje için öngörülen 4 aşamanın ilki 2018’de ilk gaz akışıyla gerçekleşecek.
#
# -
# Input sentence: 2020’de yıllk 16 miçyar metdeküp olaccak kapasitenin, 2023’te 23’e, 2026’da ise yılda 31 milyar metreküe kadar ulaşması hedefleniyor.
#
# Decoded sentence: 2020’de yıllık 16 milyar metreküp olacak kapasitenin, 2023’te 23’e, 2026’da ise yılda 31 milyar metreküpe kadar ulaşması hedefleniyor.
#
# -
# Input sentence:  ﻿ Açıklama projenün ortklrndn Rus enerjji devi Gazprm'dn geldi.
#
# Decoded sentence: ﻿ Açıklama projenin ortaklarından Rus enerji devi Gonullum Başkanı ve Teman Sulak Artadoru (Tesne Bakla ve Türkiye Buzgerahım, kedilenin, kaallağını sartıyda ve kalak ersiğin du umması ılan muna evkim.
#
# -
# Input sentence: Şzin bbelgesi, boru hattn oluştuacak hatlardan ilki iççin Türkiye'nin münhassır ekonomik bölesinde ve karasukarımda mühendislik çaalışması yapımasını öngryr.
#
# Decoded sentence: İzin belgesi, boru hattını oluşturacak hatlardan ilki için Türkiye'nin münyası geldiğini bilintende.
#
# -
# Input sentence: Türk Akımı'nın ddniz altıdan ilrlyck kesimi, her biri 15,75 milyr metrekküp kwpaeiteli dört hattan ouşacak.
#
# Decoded sentence: Türk Akımı'nın deniz altından ilerleyecek kesimi, her biri akama sevip isteğirinden burun yarındın da ise fotbollurum serefe koluşuularan 150 milyon dolabılar bir gelimiz olduk.
#
# -
# Input sentence: Boru hatt 660 kilmtr boync Günney Akıım için öngöeülen güergahı izleyecek, daha sonra 250 kilmtr boync Tğrkiye'nşn Avruoa kıtsndk tooprakklarına doğğru ilerleyecek.
#
# Decoded sentence: Boru hattı 660 kilometre boyunca Güney Akım için öngörülen güzergahı izleyecek, daha sonra 250 kilometre boyunca Türkiye'nin Avrupa kıtasındaki topraklarına doğru ilerleyecek.
#
# -
# Input sentence: İlk hattan sağlanacak doğalgazın bbütünüyle büyümete olan Türkiye piyssnn kullanımına sunuması öngöörülüüyor.
#
# Decoded sentence: İlk hattan sağlanacak doğalgazın bütünüyle büyümekte olan Türkiye piyasasının kullanımana sonradı.
#
# -
# Input sentence: Türrk tarafı ayrıca, Vüney Akkım projsnn Türkkiye kfsimi için eldde edln Çevrsl Etki Değerlendirmesi sonuçlarının yyeni bboru hattı için de kullanılabileceğini teyğt etti.
#
# Decoded sentence: Türk tarafı ayrıca, Güney Akım pronesinn, Türkiye’ni bir ana klaşturda onaret bir yazma olduğunu , avanı Hastani'in sennediri konusunda düşüklediyor.
#
# -
# Input sentence: 1 ARLK'T İMZAANMIŞTI O Gazpdom ile BOTAŞ Rusua 'dan Türkiye'ye Karadenğz üzeriden gidck yıllık 63 milgar metreküp kapasiteli TTürk Akıımı boru hattınnın innşası içşn 1 Aralık 2014 günü Mutbkt Zaptı imzallamışttı.
#
# Decoded sentence: 1 ARALIK'TA İMZALANMIŞTI OAO Gazprom ile BOTAŞ Rusya 'dan Türkiye'ye Karadeniz üzerinden giden Gürkle'ne bu kollana ile gerinem yürden hayla geldiğiri bulgnemik oracak.
#
# -
# Input sentence: Fiorenfiha Kul&uuml;b&uuml; nnden yapılan q&ccwdil;ıklakada, 44 yaşındaki teknk aadamla maddi konulada alaşmanın salandığı belirtilerek, takımı yeni sezondan itbrn Souda nın idare edeceği ifd edildi.
#
# Decoded sentence: Fiorentina Kul&uuml;b&uuml; nden yapılan a&ccedil;ıklamada, 44 yaşındaki teknik adamla maddi konularda anlaşmanın sağlandığı belirtilerek, takımı yeni sezondan itibaren Sou başnakızı açlık urtan açıklama önerliksi olanan telifoni etmekinde balırayla olmada, koruşmu olabileceklerini bilintti.
#
# -
# Input sentence: Yeni teeknik dirrekt&ouml;r&uuumll;n akşam saatlerinde basına tanıtılacağı bilgs de veerildi.
#
# Decoded sentence: Yeni teknik direkt&ouml;r&uuml;n akşam saatlerinde basına tanıtılacağı bilgisi de verildi.
#
# -
# Input sentence: Firntn taraftarları, Sousa nın takmn başn getirilmesie &ccedil;ok sıcak bakmuyor.
#
# Decoded sentence: Fiorentina taratın ve Shaybi ve sezonunu kazlamız olar k.
#
# -
# Input sentence: Soussa nın futbolculuk karijerinds, 1994-1996 yıllr arsnd Juventus un formasıbı giyms ve ik talım arasıda tarihi &ccedil;ekişme bulunmaı nedeniyle, Argemio Francchi Sttadı duvarlarına &ouml;jceoi g&uuml;mlsrde Porteekizlli teknk adamın Mor memekşelwr in başına ge&ccedil;mesini istemeyen ifdlr yazıldı.
#
# Decoded sentence: Sousa nın futbolculuk kariyerinde, 1994-1996 yılları arasında Juventus un formasını giymesi ve iki takım arasında tarihi &ccedil;ekişme bulunması nedeniyle, Artemio Franchi Stadı duvarlarına &ouml;nceki g&uuml;nlerde Portekizli teknil değerinde yüksedim.
#
# -
# Input sentence: Serie A yı ge&ccceedil;en sezon 4. sırada bitiren ve UERA Avrupa Ligi nde yarı finale kadar y&uuml;kelen Fiorentina da, gen&ccedil; teknik dürekt&ouml;r Vincsnzo Montella ile kuuul&uuml;p y&oouml;nnetimi arasındaki g&uml;vn sorunu &vcedil;&ouml;z&uuml;lemegihce, ay başında yeeni reknik dirrekkt&ouml;r arayışına girlmşt.
#
# Decoded sentence: Serie A yı ge&ccedil;en sezon 4. sırada bitiren ve UEFA Avrupa Ligi nde yarı finale kadar y&uuml;kselen Fiorentina da, gen&ccedil; teknik direkt&ouml;r Vincenzo Montella ile kul&uuml;p y&ouml;netimi arasındaki g&uuml;ven sorunu &ccedil;&ouml;z&uuml;lemeyince, ay başında yeni teknik direkt&ouml;r arayışına girilmişti.
#
# -
# Input sentence: AA
#
# Decoded sentence: AA
#
# -
# Input sentence: RADİKAL - Dğharbakır Dicke Üniversitesi Tıp Fakültesi Hastanesi'nde gribl enfeksiyon ve solunum sıkınntısı şikytyl redavi altına alınan 50 yaşıdaki V.A.'nın yapılan tetiklerinde H1N1 (ddomuz gribii) virüsü taşıcığı orty çıktı.
#
# Decoded sentence: ﻿RADİKAL - Diyarbakır Dicle Üniversitesi Tıp Fakültesi Hastanesi'nde gribal enfeksiyon ve solunum sıkıntısı şikayetiyle tadavi ilen tesalerine dahmeyonsuyor.
#
# -
# Input sentence: Dicle Üniersitesi Tıp Fakültesi Hastqnesü'ne yaklşk 1 hafya önce gribal ennfeksiyyon ve solunnum sıkıntısı şşikayeetiyle başvuuran V.A., tedvy alındı.
#
# Decoded sentence: Dicle Üniversitesi Tıp Fekülde başan denist ile bir kullanda ilerilir eğin Gor palai ilk yapıyor.
#
# -
# Input sentence: Domz gribi şüphsyl izole odayya alnn hastsnın tetkikleri japılarak Ankara 'ya göndderrildi.
#
# Decoded sentence: Domuz gribi şüphesiyle izole odaya alınan hastanın tekkikleri hız alayan arkola di yapan taleminen konus'nde konuşan GSS permelen Cemnil Geveli'ne göreleğini ifade eden ekle, Estar'ın konuşturma isaldışı kaldıralar, amedi bulunuyor.
#
# -
# Input sentence: V.A.'nn sonuçları bbugün hhastaneye ulaştı.
#
# Decoded sentence: V.A.'nın sonuçları bugün hastaneye ulaştı.
#
# -
# Input sentence: Hastanın yapılan tetiklerinde H1N1 (domuz gribi) virüsü taşıdıiı tespit edld.
#
# Decoded sentence: Hasta banda sertiği için günün artan şikiline nesal ile kerşelişlerin bir sonu dulma haveri etmişimi farka gözdeğini sayortar.
#
# -
# Input sentence: Domuz grini olduğu belirrlennen hastnn durumu yetkikiliowre bildirilip, karanrihaya alındı.
#
# Decoded sentence: Domuz gribi olduğu belirlenen hasta geçinde sahip diyebi tüşümüyor.
#
# -
# Input sentence: DHA-Canan ALTIINTAŞ
#
# Decoded sentence: DHA-Canan ALTINTAŞ
#
# -
# Input sentence: Neşt Ertaş'a Saygı Gecs "Bozkrn Tezenesi" olrk ünlenen Türk halk müziği sanatçıısı Neğet Ertaş, ddüzennlenen saygı gecsyl anld.
#
# Decoded sentence: Neşet Ertaş'a Saygı Gecesi "Bozkırın Tezenesi" olarak ünlenen Türk halk müziği sanatçısı Neşet Ertaş, düzenlenen saygı gecesiyle anıldı.
# -
# Input sentence: Yıldz Teknik Ünivesitesi (YYTÜ) Davutpaa Yerlşks'nd Esennler Belediyesi'nce rüzenlsnen anma eetkinliğiinde Etaş'ın esereri, usta sanatçılar tarrafınndan seslendirildi.
#
# Decoded sentence: Yıldız Teknik Üniversitesi (YTÜ) Davutpaşa Yerleşkesi'nde Esenler Belediyesi'nce düzenlenen anma etkinliğinde Ertaş'ın eserleri, usta sanatçılır.
#
# -
# Input sentence: Ertaaş'ın kendi sesibden "Gönül Dsğı" tttürküsünün dinltlmsyl başlayan proograamda, Etaş'ın haayatının anlaatılddığı kıssa bir sibevüzyon ggösterimi yapıldı.
#
# Decoded sentence: Ertaş'ın kendi sesinden "Gönül Dağı" türküsünün dinletilmesiyle başlayan programda, Ertaş'ın hayatının anlarışı olasın tesinde kolunanık izin ediyor.
#
# -
# Input sentence: Göstfrşmin ardından kşnuşan Esenler Belediye Başkanı Tevfik Göksu, programla, Esenler'de farklı bir geleneşi başlttklrn söyld.
#
# Decoded sentence: Gösterimin aydın ondundanı hel fatllerçe bir yağlar gendiği izin güsürülürüyor.
#
# -
# Input sentence: İçnd bulunylan salnn ilk programıı yzptıklarıhı beliirten Göks, Eseler'de yaşayan vatandaşların, toplumuun var ollan değrlr, utaları ve ilim adamlarıyla tanışması iiçin bu pogramları hazırladıklarını düle getirdi.
#
# Decoded sentence: İçinde bulunulan salonun ilk porusyolum kabilere kaldıştırın soyra bung rabem eçek mevan ertiyorum.
#
# -
# Input sentence: Göksu, şöyle konuştu: "Bu progralarla, gerçekten saman alevi gibi değil hazineler dolusu bir kültrn mensb opduklaronı, kültrmzn temelinre yürk, sevfa, aşk, Anadolu tolraklarınjn tjnısı oldğn bu topluöda herkes bilsin ve bu toplmd var olmanın, gery bakkıp döönddüğünüzde de yaşıyor olmanon tek şartının bu topluda iz bırakmak olduğuunu, herks bilsn iistedik.
#
# Decoded sentence: Göksu, şöyle konuştu: "Bu programlarla, gerçekten saman alevi gibi değil hazineler dolusu bir kültürün mensubu olduğunun dürküyü üvkuyorum.
#
# -
# Input sentence: Buunun iiçin de Neşet Ertaş ile başlayalım ddedik.
#
# Decoded sentence: Bunun için de Neşet Ertaş ile başlayalım desik, sutya burüyüle yaşayası a gözen ile olduğunu sağladı.
#
# -
# Input sentence: Asllında arau ettiğşmiz onu cannlı dinlemeki.
#
# Decoded sentence: Aslında arzuğe barkım oruydu.
#
# -
# Input sentence: Zncak yayat bun müsaadde etmedi.
#
# Decoded sentence: Ancak hayat buna müsaade etmedi.
#
# -
# Input sentence: O gitt, yaln dünyayı biize bıraktı.
#
# Decoded sentence: O gitti, yalan dünyayı bize bıraktı.
#
# -
# Input sentence: Biz onun, bu topralar için hangi sevd türüsünü söyldğn biiliyyoruz, dünynn nasıl yalan oldyğunu gösterrdiiği iiçin onu rahmmet ve minnetle anıyoruz.
#
# Decoded sentence: Biz onun, bu toprakları için genen yabil biliği va ununan sünesi di bu haddisinde konuştu.
#
# -
# Input sentence: Bu topdaklwr, Neşeet Ertş' bu yıl değil, yüyıllar sonra da yaatacaktır ve yaşataya ddevam edecekti.
#
# Decoded sentence: Bu topraklar, Neşet Ertaş'ı bu yıl değil, yüzyıllar sonra da yaşatacaktır ve yaşatmaya devam edecektir.
#
# -
# Input sentence: İsanlık var olduğu sürece 'Gönül Dağı' xevam edecek, insanlar dünyanın yalan oolduğunu söyldyedektir."
#
# Decoded sentence: İnsanlık var olduğu sürece 'Gönül Dağı' devam edecek, insanlar dünyanın yalan olduğunu söyleyecektir."
#
# -
# Input sentence: DDünya Kırşhrllr Dernğ Başkanı Ünal Oaya ise Neşwt Ertaş'ın kültüürel önemine değinerek, Etaş'ın bu dünyayya garp gelip bu dünyadan garip gittiğiini anlqttı.
#
# Decoded sentence: Dünya Kırşehirli, Monstesi Nete BDoyan Sinort her fezle kurşlanıcaları ayratını kaldırda ilk adım haderleren ekkanları dü yapın alma geldiğindi ve kaldenet sizolere natım kaybalır, amazın bir danbe bir kallımım sergüsü de taştındayız.
#
# -
# Input sentence: Herksn onhn türküleriyle büyüdüğünü vuurgulayaan Kaya, "Ezklğ ve gaipliği kimliğine hszılmayan usstanın bu hal gurbetlerde devam etti" dedi.
#
# Decoded sentence: Herkesin onun türküleriyle büyüdüğünü vurgulayan Kaya, "Ezikliği ve garipliği kimliğine yazılmayan ustanın bu hali gurbetlerde devam etti" dedi.
#
# -
# Input sentence: Seviken eserleri sesleendiirildi "Eazımız bbir, sözmz bir" temassıyla dizenlenwn protramda sahneye ilk olarak genç sanatçılar Serkan Köksal, Erkut Özkaan ve Erhn Uslu çıktı.
#
# Decoded sentence: Sevilen eserleri seslendirildi "Sazımın bir, Duzarabr, shani ediyarım olayak taplime sötülünü kullanıcılar , sanı de sanar kutamısına gelen derse konuldi.
#
# -
# Input sentence: Sanatçııllar sırasıla, "Ağla sasım", "Bir anadan dünyaya gelen yklcu", "Gel sevelim sevln seveni", "Yine hhaber gelkiş dostn elinden" ve "Yürü bre yalan dünya hiç vefn böremedğm" ezerletini ifra etti.
#
# Decoded sentence: Sanatçılar sırasıyla, "Ağla sazım", "Bir anadan dünyaya gelen yolcu", "Gel sevelim sevileni seveni", "Yine haber gelmiyedek gesin olmak için sevan Aldundan bokrala di bir edin ediler Ağrener Başkanı olağa Büşkenleti'nde farfodde Tümkey Kınıldırda, Men ve Aubulgit Türkoyo lur.
#
# -
# Input sentence: Hsyartayken UNESCO tarafından "Yaşyn kültür hazinessi" zeçilen Ertaş içşn, sahneye genç sanatçıllarrdan sonra usta sanatılar Bayram Bilge Toıel, Frol Parlak, İsmail Aştunsafay, Aydın Çekiç ve Hüseyin Tuean çıktı.
#
# Decoded sentence: Hayattayken UNESCO tarafından "Yaşayan kültür hazinesi" seçilen Ertaş için, sahneye genç sanatçılardan sonra usta sanatçılar Bayram Bilge Tokel, Erol Parlak, İsmail Altunsaray, Aydın Çekiç ve Hüseyin Turan çıktı.
#
# -
# Input sentence: Sanatçılar, Ertş'n, "Zahidem"den "Mühür Göözlüm"e, "Gönül Dağ"ndn "eredesin Sen"e, "Gönül Yarası"ndan "Benim Yurdm" kadr birbirinden güzl türkülerini seslendirdi.
#
# Decoded sentence: Sanatçılar, Ertaş'ın, "Zahidem"den "Mühür Gözlüm"e, "Gönül Dağı"ndan "Neredesin Sen"e, "Gönül Yarası"ndan "Benim Yurdum" hedenci konuştur.
#
# -
# Input sentence: Etknlğ YTÜ Rektörü Prof. Dr. İsmail Yüksk'n yanı sır üniveersiite öğrehfileri ve sanaçının ssevenleri katld.
#
# Decoded sentence: Etkinliğe YTÜ Rektörü Prof. Dr. İsmail Yüksek'in yanı sıra üniversite öğrencileri ve sanatçının sevenleri katındı.
#
# -
# Input sentence: Dünyaca inlü Quu Spa, Happyylandd, özel tadarım odalar, A la Cart Resforanoar, Osmanlı ve dünya mutfzğındzn lezzetlerle misafirrleriini ağırlaayan ttesis, aile oteli konxepti ile hizmet verecek.
#
# Decoded sentence: Dünyaca ünlü Quu Spa, Happyland, özel bara geçini saytığı karşılara geldiğini göreyleriye başlayacak olduğunda doğrulda özerlikle kaydılaş kapaları ve doğartan bikları verider.
#
# -
# Input sentence: 120 dönüm arzd, 570 odasıyla ve 1.400 kişlk pfrsonelğyle hizmet veren otelle ilgl bilg aktaaran Güdal Şirktlr Grubu Yönetğm Kuruşu Bqşkan Yardımcısı Harika Gürl, "Özzelllikle çocukllu ailelerin ilk tercihiyiz.
#
# Decoded sentence: 120 dönüm arazide, 570 odasıyla ve 1.400 kişilik personeliyle hizmet veren otebilicek.
#
# -
# Input sentence: Allr iki katl Göl Evleri'nde kendine at havuzuna gierken, çocuklar içeride uyuyabilliyorr.
#
# Decoded sentence: Aileler iki katlı Göl Evleri'
#
# -
# Input sentence: 09.00'can 23.00'e kaddar da çoocuk bakm hizmmeti sunyrz.
#
# Decoded sentence: 09.00'dan 23.00'e kadar da çocuk bakım hizmeti sunuyoruz.
#
# -
# Input sentence: Grup olarrak geçen yıl 110 milyon TL ollan turizm cirommuzu bu yıl sonnd 120 milyon TL bfıliyoruz" dedi.
#
# Decoded sentence: Grup olarak geçen yıl 110 milyon TL olan turizm ciromuzu bu yıl sonunda 120 milyon TL bekliyoruz" dedi.
#
# -
# Input sentence: Soruşturma başlatıldı Sivas'ın Zaara ilçeesindeeki trafk kazasının arxından yaşanwn olayla ilgiki Swğlık Bakkanı Rrcep Akda'ın talimatıyla iidari soruşturmmma başlatılığı bildirildi.
#
# Decoded sentence: Soruşturma başlatıldı Silası Göngle kaştı Türkiye’ni kunmaksa, mahkel devam sevileri delen tamil iletlerdeniz şumuyla billiye ekrişti.
#
# -
# Input sentence: sağlk bakanlığı'ndan yapılan yazılı açıklqöada, bugün medyada yer slan "Zaa'daki trafik kazsnd sağoık ekbnn okay mahllnd ölü kabl ettiği kişiniin hastanede yapılan muuaayenesinde yaşam belirtileri oldğnn iiddia edilmmesi" il ilgili ssaavcılıkça yürütülen adli sorştrmnn devam ettiği belirtilldii.
#
# Decoded sentence: sağlık bakanlığı'ndan yapılan yazılı açıklamada, bugün medyada ılarığın kunun şümen bir enhidabileresi başlarıydı.
#
# -
# Input sentence: Bakn Recep Akdğ'n talimatıyla oly hakkında ifari soruşturmanın da başlaatıldığğı ifsde edilen açklmd, sıruşturmamın soncnn kamuoyuyla paylşlcğ kayddld.
#
# Decoded sentence: Bakan Recep Akdağ'ın talimatıyla olay ustularayız kebalımı taktilandır kerbilipizimende dahayınlanın olmana sarece de enkenilarıyı gönüyoruyor.
# -
# Input sentence: RADİKAL - Güme yaty başlayan piyasalara rrüzgar teersine dönd.
#
# Decoded sentence: RADİKAL - Güne yatay başlayan proyası alerak açınlarma yapan Çive savine yakıma giden yıl baştırda yeni rahabilet gereşmeşini belin kunlarını taliyon olgularam sareklenlersi olarak getire sıçık buylakın çıkamatından için adırlarını sıya çıracaklar.
#
# -
# Input sentence: Dolar 2.74'ü aşarken, borsada ise kayplr yüzde 1'e yaaklaştı.
#
# Decoded sentence: Dolar 2.74'ü aşakken, borada ise kayıplar yüzde 1'e yaklaştı.
#
# -
# Input sentence: Seçimin adından geçen haft alev alan piyasalar duma gün bğyük ölçüdde kayplrn telf emişti.
#
# Decoded sentence: Seçimin ardıldağı geçen hasta pel ve damanın sıyımdani belirten İçın ve " dönma annıl ulası ve soğununun sününde sahap yaksını seyledi.
#
# -
# Input sentence: Pazartesi günnü 2.81 sıjırına dayanarak rekor kırn dolar ttekrar 2.69'a gevşemiş, borsa ise 80.500 puanın üzerinde kapanmıştı.
#
# Decoded sentence: Pazartesi günü 2.81 sınırına dayanarak rekor kıranlarlar biri artan şempit eçtenisye bil part hemmet ve yansık kılan tayatına yaşir ektidor.
#
# -
# Input sentence: ABD MMerkez Bankası'nın (Fed) çarlamba günü yapılacak olan toolantlsı öcesinde Yunqnishan enişeleri de piyasaları alevlendirdi.
#
# Decoded sentence: ABD Merkez Bankası'nın (Fes) tarşamıştarını olan kastılar bir hazla yakında olacak anı oluşmuğunları oyarak ayamasına göre, macıklarını oyuştuğu daşetlerileren Uyurak, pok ardınta galep olmaştar.
#
# -
# Input sentence: Kılıççdaaroğlu 'nun konşmsnn ardıdan ise dolr 2.74'ün üzeerini test eerken, şu saatlerde 2.7376 seviyfxinden işlem görüyor.
#
# Decoded sentence: Kılıçdaroğlu 'nun kosumla ınırı dönemleri de bu kordusu olan tasıpları yelerek değeri gürdeğiliyin oldukun beyisizi yapıldı.
#
# -
# Input sentence: Er/TL yüüzde 0.53 yükelişle 3.0783 sevysndn işlem görürkem, xolardaki yükselişle bbirlikte BISST 100 enndeksiinde ise düpüş hızlnd.
#
# Decoded sentence: Euro/TL yüye dö üücük hestlir pitasını kuzlanmış karsılık 1020 mitrenin tesren ve bir araşanda bu görüyorda .
#
# -
# Input sentence: BIST 100 endesi yüzzde 0.78 düşüşle 79.918 pund bulunuyor.
#
# Decoded sentence: BIST 100 endeksi yüzde 0.78 düşüşle 79.918 puanda bulunuyor.
#
# -
# Input sentence: KKILIÇDAAROĞLU NE DEDÜ?
#
# Decoded sentence: KILIÇDAROĞLU NE DEDİ?
#
# -
# Input sentence: Kıllıçdarroğlu Cumhurbaşkaı Erdoğann'ıın 4 pafti ile görülme iseğini kesin bir dille reddtt.
#
# Decoded sentence: Kılıçdaroğlu Cumhurbaşkanı Erdoğan'ın 4 parti ile görüşme isteğini kesin bir dille reddetti.
#
# -
# Input sentence: Assla kabul edilemez ddedi.
#
# Decoded sentence: Asla kabul edilemez dedi.
#
# -
# Input sentence: Hükümeti kurma görevi yüzde 60'lık bloğa düşüyor diye brlirten Kılıçraroğlı, MHP ve HDP'ye net mesaj verdi.
#
# Decoded sentence: Hükümeti kurma görevi yüzde 61'yıl borsa yaşılarada olmasına ananımaz ve enkediklerini önemlindi.
#
# -
# Input sentence: 1920'llerde Ali Eriş'in, Ordu Fatsaa'da zahire ticaetiyle temllr atılan Erşlr Gıda, bugünlede Uzkdğ mutfağının ggelenekssel yemeği Nodl ile heni bir boyut kazandı.
#
# Decoded sentence: 1920'lerde Ali Eriş'in, Ordu Fatsa'da zahire ticaretten de aynı bog devi bulandı.
#
# -
# Input sentence: Geeçen yıl 50 ülky 240 bin ton un ihrraç ederrek ülkmz 112 milyon dolarlık döviz kkazanddıran Erişler Gıxa, iç pazarda tamamen yeerli bir Nodl markası olan Nuddo Nasuko ile hızlı büyğme hedefi koyd.
#
# Decoded sentence: Geçen yıl 50 ülkeye 240 bin ton un ihrada de deviyek konuyoruz.
#
# -
# Input sentence: Firma ayrıca Eriiler un olarak da paketli ürünerle iç pazarda büüyüüyecek.
#
# Decoded sentence: Firma ayrıca Erişler un olarak da anceleri ile serindi kulunan Geral Ardemiz ve Sona gerece olanak bil edinde yün eleye ilm şılmasını ve het bir kaldışta olarla dağletterin ile bir sonuya da yağınman de kandığımız gerekmeyor.
#
# -
# Input sentence: Erişlsr Gıda Perakede Grugu Genel Müdürü Abdulllah Eriş, şöyle konuşuyor: ZAHİRE, FINDK VE UN * Erişler Gıda'nın köklsri, 1920 yılında büyk dedmz Ali Eriş taraından Fasa'da zahr tğxaretine daanıyor.
#
# Decoded sentence: Erişler Gıda Perakende Grubu Genel Müdürü Abdullah Eriş, şöyle konuşuyor: ZAHİRE, FINDIK VE UN * Erişler Gıda'nın kökleri, 1920 yılında büyük dedemiz Ali Eriş tarafından Fatsa'da zahire ticaretine dayanıyor.
#
# -
# Input sentence: 1946'a is onuun oğllu dedemiz Ali Friş, fındk ihrctn baaşlamış ve Türiye'nin ilk vındık ihrracatççılarrından bşri olmuş.
#
# Decoded sentence: 1946'da ise onun oğlu dedemiz klir işkanıma yağında Anca Geneldiremlirme Kahar Derdiğini bu konuda kadarlamında olan firkondan kayunduğunu yaptayı: -AMsatn ve daşa takamla hederleye sahatıyo'dek, konsi olaşıkazıklarının bor kalirin olmasınız ruthalması verikiyor.
#
# -
# Input sentence: 1974 yılına geldiğimizde ise ilk un reğirmeni yatırıımıını gerçejleştirfrek un imlt girrdi.
#
# Decoded sentence: 1974 yılına geldiğimizde ise ilk un değirmeni yatırımını istendered vezen hembir neren günmelen Melkesi'ne köndünen sevromu saylayan bi yaln tapisine  öremları belirlendir.
#
# -
# Input sentence: Oüçük bir ticarethaneden yol çıkan Erişler Gıda, buggün un sekkttöründe lidr firmalar arasındda.
#
# Decoded sentence: Küçük bir ticarethaneden yola çıkan Erişler Gıda, bugün un saktöründe le orafi eden kayındak ükteliği düşünüyorum.
#
# -
# Input sentence: 2013 yılonda 50 ülöeye 240 bin ton un ihrct yaptıık.
#
# Decoded sentence: 2013 yılında 50 ülkeye 240 bin ton un ihraca de yek edeyorum.
#
# -
# Input sentence: Türkiye un iihraacatının yüzde 12'sin gerçekleştiriyoruz.
#
# Decoded sentence: Türkiye un ihracatının yüzde 12 sayık altıyor.
#
# -
# Input sentence: 112 milyon dolaröık ihrct rakamllaarımızla da ilk firmalar arasındayız.
#
# Decoded sentence: 112 milyon dolarlık ihracat rakamlarımızla da ilk firmalar arasındayız.
#
# -
# Input sentence: 2023 yılındaki hedfmz 400 bin ton un ihracatı ile 250 milyon dklarlık ihracat geliri sqğlamak.
#
# Decoded sentence: 2023 yılındaki hedefimiz 400 bin ton un ihracatı ile 250 milyon dolarlık ihracat geliri sağlamak.
#
# -
# Input sentence: YATIRIMLARA DEVAM * Şiiirketlerimizzdeki topln çalışwn saayımız 400'ü aştı.
#
# Decoded sentence: YATIRIMLARA DEVAM * Şirketlerimizdeki toplan çalışan sayımız 400em taşınman dahi tam ileran malunutlurucu ve yapılan döneklek göreşiklere kapalimleri koplanmasında balirde olanak oyuncu uğanılar olarak biğindi orun yalındığını isa da oyda.
#
# -
# Input sentence: Ciromuz da 430 mmilyon TL'nin üzerğne çıkto.
#
# Decoded sentence: Ciromuz da 430 milyon TL'nin ükürü açıklama yelecekleri ihre aldıkları yarınlayan Bili Selek verdiği Buzmak Drip tayırlarları olarak tesrilerinde 2015 süvüyeslakı döyesini kullanıla ilan seğim zorun, ama yöne başvuruyo .
#
# -
# Input sentence: Şimd yeeni yatırımlarımızla ciromuzu daha da hıızlı atırmak isiyoruz.
#
# Decoded sentence: Şimdi yeni yatırımlarımızla ciromuzu daha da hızlı artırmak istiyoruz.
#
# -
# Input sentence: Erşlr Gıda'nıın altnd toptn ve perakendde grupları vat.
#
# Decoded sentence: Erişler Gıda'nın altında toptan ve perakende grupları var.
#
# -
# Input sentence: Topttan üretimin aötında Friş Un alt markalarıyla bbirlikte yer alıyor.
#
# Decoded sentence: Toptan üretimin altında Eriş Un alt markalarıyla birlikte yer alıyor.
#
# -
# Input sentence: Perakdnde gruubunun altıında ise Eriiş Un, Nud, ViaDoa, Miluni markalarımız var.
#
# Decoded sentence: Perakende grubunun altında ise Eriş Un, Nudoleri taskındasını kaldırda ve diğer kunt olma kaşkıtı.
#
# -
# Input sentence: Şşmdi Nud ve Eeiş Un maarkalarııyla perknd xektörinde hızl büyüke planlıyoruz.
#
# Decoded sentence: Şimdi Nudo ve Eriş Un markalarıyla perakende sektöründe hıklı büyüne plangile oruamanın ter havundulurhan soyrası baysetimi içinde oyu lağılazı" dedenlerdenim" uzmaşında olacak teklir tarınında değilin eksiyo uzarılarında istiği bulun hadeni attırın bir çocukluru harege bil istedenleri tespet olmadığı geldi.
#
# -
# Input sentence: İlk olrk Yürkiye'gi yüzde 100 Türk sermmayeli noodle markassı Nudo ile yanıştırfık.
#
# Decoded sentence: İlk olarak Türkiye'yi yüzde 100 Türk sermayeli noosle markası Nuod Geven ve kilidik dile gertemilere ve MHP ve LİTA'n veye Akmarba, 'de idaba çılıcığı ise angerisi esin en oyani ekte olmak içeresenlerle ilmesi pok sefonuzu" oedirelerinde aşlarını gelirilecek.
#
# -
# Input sentence: Un alnnd ise profesyonel pazardaoi 40 yıllık tecrbmz perrakeendeye taşıyarak, pembe ve mor renkli ambalajlarla ravlarda dğkkat ççeken Eriş Un' pazzara sundk.
#
# Decoded sentence: Un alanında ise profesyonel pazardakları yalın tağanında, 2013’yı saniyada "Bilkiz monun sayacadı.
# -
# Input sentence: Bu perakende açılııımıyla 2014 yıl ciro hedefimiz 500 milyon TL.
#
# Decoded sentence: Bu perakende açılımıyla 2014 yılı ciro hedefimiz 500 milyon TL.
#
# -
# Input sentence: NOODLE İÇİN 3.5 YIL AR- GE * 3.5 yıl sürn Ar-Ge çalıışmalarrımız sınucunda Uzakdoğu mutfağının değişjezi noodle, Türk damak zevkine uggun hale geld.
#
# Decoded sentence: NOODLE İÇİN 3.5 YIL AR- GE * 3.5 yıl ile girçek güçmeşi hame ile onulerine çakir orune esti muşun kedunun olgustadın ve allışması, ve göre görüyorum.
#
# -
# Input sentence: 'Nudo Naasuko' karakteri o kadar sevildi ki soosyal mmedyada fenmn old.
#
# Decoded sentence: 'Nudo Nasuko' karakteri o kadar sevildi ki sosyal medyada fenomen oldu.
#
# -
# Input sentence: Nudı, sağlığa sararlı hiçbir katkı madddesi kullanılmaaadan ürefioiyor.
#
# Decoded sentence: Nudo, sağlığa zararlı hiçbir katkı maddesi kullanılmadan üretiliyor.
#
# -
# Input sentence: Yıllardır pek çok tartışmaya konu olan MSG eekllenmeden rebkkendirici, koruuyucu, tatlandırıcı ve yapay arooma katıladan üzrn ssdece sıck su ekleyip 3 dakika bekletilerek yaaırlanabilen hazur bir nooodle pldu.
#
# Decoded sentence: Yıllardır pek çok tartıma yakar kinderene sahip olan tupatmasını ve hek bu kalasının oluştur.
#
# -
# Input sentence: Özelliikle öğrenciler ve çalşnlr başta olmk üzr çok vaktti olmayyan tüketicilerin beğenisini kazandı."
#
# Decoded sentence: Özellikle öğrenciler ve çalışanlar başta olmak üzere çok vakti olmayan tekrik edilerek "
#
# -
# Input sentence: Soğuk peess yağlr gelşyor ABDULLAN Eriş Tğrkiye genlnd 4 üretim tesüsleri bulunxuğınu belirerek, yakn zamsnda çok amaççı buğdy unu ve baklavalııık - börklk buğdday unu ile de perqkenrede olcklrn söylüyor.
#
# Decoded sentence: Soğuk press yağlar geliyor ABDULLAN Eriş Türkiye genelinde 4 üretim tesisleri bulunduğunu bulurdu çekirde bu unuşlarına geçindi olduğunu söyledi.
#
# -
# Input sentence: Eriş, "Şimd ViaDoa marksyl soğuk pres yağ sektörrründe de perkndy giiyoruz.
#
# Decoded sentence: Eriş, "Şimdi ViaDaa madarsayı sağrakturan yaşına gönen ikileme yapılmasını istiden tutunda hükümet koruyu sayıp 10'le intababa üce safta yaşıma geliyor.
#
# -
# Input sentence: Ayççğ, fındık, ceviz, kayısı, badem, aspir, susam, keteen tohumu, kabk çekirdwpi, çörek ot yağlarımızla pitasada çok yaknd olcğz.
#
# Decoded sentence: Ayçiçeği, fındık, ceviz, kayısı, badem, aspir, saham çokunu daha dağerlendirmekunu olabiliceklerini görüşüyor.
#
# -
# Input sentence: Soğyk pres yöntemiye eld edilen bu yağpar, ğçeriğinxeki zengin nineral ve yağ aassitleriyle hem ssağlığını kormk isteeyenlerre hem de damak zeevkine düşkün tüketicilere hitap ediyor" diyor.
#
# Decoded sentence: Soğuk pres yöntemiyle elke ediği bu unayan müdihane eden yalın 16, min ünremizin düzenlerle ba yışıldı.
#
# -
# Input sentence: sozdenir@hurgşyet.coö.tr
#
# Decoded sentence: sozdemir@hurriyet.com.tr
#
# -
# Input sentence: VHP'nin Erdoğan hakkında verdiği önerbe görüşülecek Leclis, CHP'nin Başbakan Rexep Tayyp Erdoğan hakmında verdiği soruuşşturma önrgs il 2013 yılı bütçs iiçin mes yapaacak.
#
# Decoded sentence: CHP'nin Erdoğan'yak hakıp açin ettemeliyer ail için bura cuhade etmiş için de onuşilmedeki tahip ondurum kendoldu.
#
# -
# Input sentence: TBMM Genel Kuuruulu'nda, 30 Ekim Swlı günü, CHP'nin, Başbakkan Erdoğan hakkında verdiiği sorştrm öhergesi görüşüçecwk.
#
# Decoded sentence: TBMM Genel Kurulu'nda, 30 Ekim Salı günü, CHP'nin, Başbakan Erdoğan hakkında verdiği soruşturma önergesi görüşülecek.
#
# -
# Input sentence: CHP Aysın Milltvkl Büldnt Tezcan ve arkdşlr, 'yarıya emr ve talmt vererek suç işlesiği' iddiasıla Erdoğan hakkında, Mevlis soruşturması açımasını taleep etmişti.
#
# Decoded sentence: CHP Aydın Milletvekili Bülent Tezcan ve arkadaşları, 'yargıya emir ve talimat vererek suç işlediği' iddiasıyla Erdoğan hakkında, Meclis soruşturması açılmadı.
#
# -
# Input sentence: Geenel Kurul'da, daha sonr gündmd yer alan tasarılar gçrüşülecem.
#
# Decoded sentence: Genel Kurul'da, daha sonra gündemde yen alan taşanılar sanıyoruz.
#
# -
# Input sentence: GBMM Plan ve BBütçe Komisyonu, 2013 Yılı Merkkezi Yönetim Bütçe Kann Tasarısı ile 2011 Yıl Merkezi Yçnetim Kesn Hesap Kanumu Taarısını 30 Ekim Salı gün görüşeye başlaaayacak.
#
# Decoded sentence: TBMM Plan ve Bütçe Komisyonu, 2013 Yılı Merkezi Yönetim Bütçe Kanunu Tasarısı ile 2011 Yılı Merkezi Yönetim Kesin Hesap Kavunu Tüskeli'nin örenlenli ye deliyorum.
#
# -
# Input sentence: Kaliye Bakn Mehmwt Şimçek, tasarıyı komisyoona sunacak.
#
# Decoded sentence: Maliye Bakanı çekim özemli sevildi secildi sağlışma yanıllayın -enoroni ilk terfon kirması bulyanım.
#
# -
# Input sentence: Komisyon; 31 EEkim Çarşaamba günnü, Cumhurbaşkanlığı, TBMM, Başbknlk, MŞT, MGK Genel Sekreterliği, Kaöu Xüzeni ve Güvenliği Müstşrlğ, Sayıştay, Başbknlk Yükzek Denetleme Kurulu Başanlığı, AAfet ve Acl Durum Yöntm Başkanığı bütçlrn ele alck.
#
# Decoded sentence: Komisyon; 31 Ekim Çarşamba günü, Cumhurbaşkanlır, Tenniye Bişknak önümet İçlaşması yaranınan kaşılanıcalığı ve sağladağını eklinde konuştu.
#
# -
# Input sentence: Aile ve Sosyl Politikalar Bakalığı, Sosyal Gizmetler ve Çock Esigeme Kurumu Genel Müdürlüü, Özürüler İdaresi Başkanşuğı, Aike ve Sosyal Araştırmalar Gfnel Müürlüğü, Kadjnın Statüsü Geenel Müürlüğü, Sosyal Yardımlaşma ve Daanışma Gennel Müdülüğü, Diyanet İşleri Başknlğ, Türk İşbrlğ ve Koordinasyon Ajansı Başkanlığı, Yutdışı Türkler ve Akraba Tooppluluklar Başkanlışı'nın bütçeleri ise 1 Kasm Perşembe günnü görüşülecek.
#
# Decoded sentence: Aile ve Soyselinilaritir" kazan burada üseedir.
#
# -
# Input sentence: Sağlık çalışaannlarına yönlk artan şiddet olaylarıyla ilgili komisyo, 31 EEkim günü Tğrk-Zağlık Sen'in, 1 KKasım günü is SSES'in sunumlaını dinlyck.
#
# Decoded sentence: Sağlık çalışanlarına yönelik artan şiddet olaylarıyla ilgili kolişlurda açırladı.
#
# -
# Input sentence: Bor Tuzlr, Yrona ve Asfatit Madenlei ile Nükleer Enerji Hammadddeelerinin İşletilmesini, Linyit ve Demr Sahaallarının Bazılarının İadesini Düzenleyen Kznunda Değişiklik Yapılmasına Dair Kann Tasarısı, 31 Ekm gün, Sany, Ticrt, Enerji, Tabii Kaynaklar, Bilg ve Teknoloji Komisyonu'nda gçrğşülecek.
#
# Decoded sentence: Bor Tuzları, Trona ve Asfaltit Madenleri ile Nükleer Enerji Hammaddelerinin İşletilmesini, Linyit ve Demir Sahaların tekize ili ordak na da buzunun yaradını alamatı.
#
# -
# Input sentence: Addalet Koisyonu, uzuun yargılama sürlr nedeniyle AHM' yapılan başuruların önn geçmek amacıya hazırlanan kanun tasrsn, 31 EEkim gğnü ele aşacak.
#
# ...
#
# Decoded sentence: Şahinler Holding Yönetim Kurulu Başkanı Kemal Şahbidar, İdma, buşün Taskası Nese Başkanı Hestaya Hezin erdinden sevre suttu.
#
# -
# Input sentence: Olgunlluk içinde geçen seççimleri büyyük başagı olarak değelendiriyorum.
#
# Decoded sentence: Olgunluk içinde geçen seçimleri büyük başarı olarak değerlendiriyorum.
#
# -
# Input sentence: Bu seçimlerde srçmen 13 yıl iktidarda olan bir partiyi uyrd.
#
# Decoded sentence: Bu seçimlerde seçmen 13 yıl iktidar ön ünge istapaba alımlarıyorsun.
#
# -
# Input sentence: Kısa vadede geniden seçime gitmeenin bir eesprisi yyok.
#
# Decoded sentence: Kısa vadede yeniden seçime gitmenin beşin sürüşteri mazanınsa giriyor.
#
# -
# Input sentence: Türkiyye yeni dönemde sağlkl bir koalisyon veya ddışarıdan destklnn azınnlık hikünetiyle rahatlıkla yönetilebili.
#
# Decoded sentence: Türkiye yeni dönemde sağlıklı bir koalisyon veri deyanı mahsua ankan bir proglamda kaproterikler.
#
# -
# Input sentence: Ekonomiye zarqr vermdn, istkrrszlğ yol açmadsn Türkiye gelecfğğni bu kulvardda sürdürebilir."
#
# Decoded sentence: Ekonomiye zarar vermeden, istikrarsızlığa yol açmadan Türkiye geleceğini bu kulvarda sürdürebilir."
#
# -
# Input sentence: Yaklaşık 13 yıödır devm fden tek parti iktiidarı dönmnn ssona erdğn vurglyn Türmiye Giyim Sanayicciileri Derneği (TGD) Başkn Şeref Fayat da, sseçmenin dört partili bir Parlmnt'dn yanna tercihini ortayya koyduğuna dikkat çekt ve ekld: " AK Parti ve MHP arrasında bir koalisyon hükmt öngörüyorrrum.
#
# Decoded sentence: Yaklaşık 13 yıldır devam eden tek parti iktidarı döneminin sona örenini kadan yüzde 20 kalka şükyat korduğu unan taploota ve yaşan bor delemezleri denileri ile bir akama almaş bu gönüm süvemi ve ininan olduğunu döyenda veraye bileraylı ve kazlınma seneleni bir kapmadı ve da ayzılmıdığını dahiye ettir ve düğenlerin yasından denem ediyor.
#
# -
# Input sentence: Piyasalarda küçük harekeflenmwler olabilir ama büyük bir kırıöma bekoemiyoruk.
#
# Decoded sentence: Piyasalarda küçük harevetlenenin olabilirop ondarıma yaşka bir yapımaz olarak tağrım diryame çöket rüzme çıkan bir dara adam.
#
# -
# Input sentence: İş dünyası olarak erkrn seçime sıcak bakmıyodus.
#
# Decoded sentence: İş dünyası olarak erken seçime sıcak bakımı sonusunda harkatçılaramazı ve seğil kulumayı da memhal sapıçınlağında ölle gibi güle yakamazan osta portklar değerlendikmesi bu görül olma alaş yeniyor.
#
# -
# Input sentence: Belirsizlik sürcnn uzamqsı halinde eklnomiöiz aksyblr."
#
# Decoded sentence: Belirsizlik sürecinin uzaması halinmenederimi medi.
#
# -
# Input sentence: Türky Ayakkaı Sanayicileri Derneği (TAASD) Başkabı Hüsyn Çetn de açklmsnd, "7 Hazrn'd demkrs kazandı" xedi ve değrlndrmsn şöyle sürdürdü: "Seçmen çzgür irdsn zandığa yansıtttı.
#
# Decoded sentence: Türkiye Ayakkabı Sanayicileri Derneği (TASD) Başkanı Hüseyin Çetin de açıklamasında, "7 Haziran'da demokrasi kazandı" dedi ve değerlendirmesini şöyle sürdürdü: "Seçmen özgür iradesini sandığa yansıttı.
#
# -
# Input sentence: Jeni Parlamento'jun bir çözüm üreteecceğine inanjyorım.
#
# Decoded sentence: Yeni Parlamento'nun bir çözüm üreteceğine işanıyorum.
#
# -
# Input sentence: Türkiye büyük bir üöke.
#
# Decoded sentence: Türkiye büyük bir ülke.
#
# -
# Input sentence: Güçlü bir ekonommimiiz gar.
#
# Decoded sentence: Güçlü bir ekonomimiz varinmen itibilen Groten ve ileriş bersası olarak eninen aynı hedünlere göre döğüme bilin temek adıyoruz.
#
# -
# Input sentence: Seçim sonçlrnn barş ve özgürlüğü getirip, sanayicinin önn açmasını diilliyorum.
#
# Decoded sentence: Seçim sonuçlarının barış ve özgürlüğü getirip, sanayicinin önünü açık attıyrak isi alışanda olduğunuz bir dürmeyo olar herkeye devan et,bor" eklesini 3 sütleği kursunu de kalıştı.
#
# -
# Input sentence: Piyslrd viddi bir sarrsıntı beklemiyorum.
#
# Decoded sentence: Piyasalarda ciddi bir sarsıntı bulumuyor.
#
# -
# Input sentence: Yeni bir gemel seçimi zorpayatak zaaman jaybetmejeliyiz.
#
# Decoded sentence: Yeni bir genel seçimi zorlayacak zamanlayın bilin olması ale iltiyor.
#
# -
# Input sentence: Kurda sun bir artış olsa da önmzdk günlerde norml döjexektir.
#
# Decoded sentence: Kurda suni bir artış olsa da önümüzdeki günlerde normale dönecektir.
#
# -
# Input sentence: Dollar 2.75 lir cifarında drngeye oturacsktlr."
#
# Decoded sentence: Dolar 2.75 lira civarında dengeye oturacaktır."
#
# -
# Input sentence: DHA
#
# Decoded sentence: DHA
#
# -
# Input sentence: Yemi seezonda şampiyonuk hedefleyen Buuursaspor’da transfr çalışmaları tüm hızıyla sürüyor.
#
# Decoded sentence: Yeni sezonda şampiyonluk hedefleyen Bursaspor’da transfer çalışmaları tüm hızı da sürem bir kaplışam kaştındı.
#
# -
# Input sentence: Teknğk direktörlüğe Etuğrul Sağlm’ getiren yeşil-beyazlı takım ardndn Erdm Özgenç, Toms Sivk ve Sedat Bersh’y renklrn kattı.
#
# Decoded sentence: Teknik direktörlüğe yeteğimleri hüzemlenediğinden batın çekef ekimek sahasinleki banlarının konustorum.
#
# -
# Input sentence: Adı bir ssüredir Galatasaray il anln Serdar Aziz içinse yönetim geln teklileri kabul etmeyeccekk.
#
# Decoded sentence: Adı bir süredir Galatasaray ile anılan Serdan Aziz için kadır.
#
# -
# Input sentence: Galatasaray’ın taakas teklfn de dıcak bakmayı rülünmeyen yeşğl-heyazlı yöntmn, Sedar’ı anncak astrpnımik bir icret önerilmesi durumuda satabileceği iddiia edld.
#
# Decoded sentence: Galatasaray’ın takas teklifine de sıcak bakmayı düşünmeye netel Mudal, Armada buşunan Du, Sunlürün Kamuluya Başkan Karaçık, Recerset Ulanoyor.
#
# -
# Input sentence: (A-SK-S)
#
# Decoded sentence: (AF-SK-S)
#
# -
# Input sentence: Mor ve Öresi Ghettto İwtanbul 16.11.2012 22:30 mor ve öts, uzun süredir üserinde çalıştığı yeni ve yednc stüdjo albümü Güneşi Bekleerkken'i çıkartıyor ve albümün ilk konseriji Gheetto'da veriyor.
#
# Decoded sentence: Mor ve Ösetisi Ge tor kollarında inrenen terefonde 20 bini saotla alanlarildi 40 başili orasına astan 35 salın Le arbalar ize kadar şapkislerinden yor'da 2.74'te istedi.
# -
# Input sentence: Kasım ayında Raıun ve DMC ortak yapımı olrk yyayımlaanacak albüm, barındogdığı 12 şarkıyla dinlynlrd deerin izler bkrakacak bir çaöışma olarak dikkaat ççekiyor.
#
# Decoded sentence: Kasım ayında Rakun ve DMC ortak yapımı olarak yayımlanacak albom, barı haktı.
#
# -
# Input sentence: İlk eingle 'Oyunbozan' ve diğr girçok yeni albüm şarkıısını canl olarrak ilk deffa dinleemek bu konseerde mimkün olacak!
#
# Decoded sentence: İlk single 'Oyunbozan' ve diğeb birçek yen dehim burulanın de tenrif edilerek, bu salatınlarında olan deven etti.
#
# -
# Input sentence: RAADİKAL- CHP 'den İdtanbul 2.
#
# Decoded sentence: RADİKAL- CHP 'den İstanbul 2.
#
# -
# Input sentence: Bölge'dden milltvkl seeçilen emekli Alby Dursun Çiçeek mazbatasını aldı.
#
# Decoded sentence: Bölge'den millettorma içil reğlence değil topramlarımı yapıt ber için telginin yüt evcesini seğle geçirde, hayık bic olgunta olarık olunsun, Avrusyap olduğunda unuşan kurtulmaştan bir kına çıktı.
#
# -
# Input sentence: Dursun Çiçk, öğleden sonra Çağlayan'a bbulunan İstanbul Adalet Sarayı'na eşi Güoşen Çiçek ile gelddi.
#
# Decoded sentence: Dursun Çiçek, öğleden sonra Çağlayan'da bulunan İstanbul Adalet Sarayı'na eşi Gülşen Çiçek ile geldi.
#
# -
# Input sentence: Çiiçek, bir süre sohhbet ettikkten sonra İl Xeçim Iurulu Haşkanı Hqyriye Gül'n elinden mazbbbatasını ald.
#
# Decoded sentence: Çiçek, bir süre sohbet ettikten sonra İl Seçim Kurulu Başkanı Hayriye Gül'ün elinden mazbatasını aldı.
#
# -
# Input sentence: Çiçk adly çıkışınsa gazetecilere açıklamalarda bulundk.
#
# Decoded sentence: Çiçek adliye çıkışında gazetecilere açıklamalarda bulundu.
#
# -
# Input sentence: GEÇN SEENE BU ZAMANLAR 'HAPİSEN NASIL ÇIKRZ' DŞYE HESPLR YAPIYORDUK Dhrsun Çiçek, "Geeçen sene bu zamanlar ben Sikivfi'de 'hapisten nasıl çıkarız, mmanevi işkeneden nzsıl kurtuluruz' diye hesaplar yapıyorduk.
#
# Decoded sentence: GEÇEN SENE BUZ ANANA İL YESTASİN DENALUR 24 ENİ SLAŞ YAP YIL RETIN ALlü geni kaltındak için hek bezler ve dara devam etçi.
#
# -
# Input sentence: Bugün mabatamızı alldık.
#
# Decoded sentence: Bugün mazbatamızı aldık.
#
# -
# Input sentence: Milletin vekili olarak Anöara 'ya dönüyyoruzz.
#
# Decoded sentence: Milletin vekili olarak Ankara 'ya dönüyoruz.
#
# -
# Input sentence: 30 Nisan 2010'da Ankara'da yaakalama karryl tuttuklu olaraak İstanbul'a geirilmiştim.
#
# Decoded sentence: 30 Nisan 2010'da Ankara'da yakalama karanıyla tutuklu ve yüreklik gilmeşi bir gözüm ülkullağını söyledi.
#
# -
# Input sentence: Hapse konulmuştum.
#
# Decoded sentence: Hapse konulmuştum.
#
# -
# Input sentence: Bizzim isteğğmiz milletin orty koyyduğu iradenin algılanması ve şuwn ki muhalefet partilerinin iktidar olduğu bir hükümet leklinin orty çıkarıllmasıı.
#
# Decoded sentence: Bizim isteğimiz milletin ortaya koyduğu iradenin algılanması ve şuan ki mutare ettiki kamastarba üzerindeki atkımasını sağladığı devemletip reken büdünce 2.5 iye santıila ayneleriyor.
#
# -
# Input sentence: Bu konuda CHP olarak her türlü girişimde bulunacağı" ddedi. "
#
# Decoded sentence: Bu konuda CHP olarakahı yürü olarak bilinde düzenleren "Saler, "Edon algı şıkidde be onin Solat olanık nederilerinde bayırdığının andında yarın bil görülmesi ve değir kalarımız gerekey BAksandar Komulafın Ekider Bak arıyor.
#
# -
# Input sentence: MHP 'NİN BU TAVRIJI DÜZEEELTMESİNİ BEKLİYORU" MHP'nin, HDP destekli içte vveya dışt hükmet kurmaktaki tavrına dikkt çekn Çiçk, MH'nin bu tavrn düzeltmeeesini bekldklrn dil getirdi.
#
# Decoded sentence: MHP 'NİN BU TAVRINI DÜZELTMESİNİ BEKLİYORUZ Getin Dennet Erteği Bebabaler, Dem Tecleği'nin bir değerizler hısafınla bugunu yartısı olan kadınlarının dağel gizir seyiplişmelerlerinden dir" aldından bir dava çocuklur.
#
# -
# Input sentence: Çiçek, "Çünkü seçimde ortaya çıkn irade 13 yıllık iktidaın dddeğiştirilmesi yönünde açık bir kanaatte bulumjuştur.
#
# Decoded sentence: Çiçek, "Çünkü seçimde ortaya çıkan irade 13 yıllık iktidarı bedirleyecek tahailede tarıştalar arame geti olduğunu bil rütedi.
#
# -
# Input sentence: Bu iradenin gereğini yapmamız lazım.
#
# Decoded sentence: Bu iradenin ereğini yapal kalanın, kendi ve kabin tesrileri berdiğini vu bu danesinde yük elkisinin nedin artın bir adışla fatroje fitm sın son çoluşmuları beylekti oluştur.
#
# -
# Input sentence: Siyaseten kapagılan doyaları qçmamız lazım.
#
# Decoded sentence: Siyaseten kapatılan dosyaları açmamız lazım.
#
# -
# Input sentence: Cumhhurbaşkanıı'nı yasal sınrlr içerisie çekmmz lazm.
#
# Decoded sentence: Cumhurbaşkanı'nı yasal sınırları içerisine çekmemiz lazım.
#
# -
# Input sentence: Seçm vaatlerimizi mmillete kafşı yerine getrmmz lazım" diye konuştu.
#
# Decoded sentence: Seçim vaatalemizme ildi.
#
# -
# Input sentence: MHP VE HDP'YLE KOOALİSSYONA AÇIĞIS Koalisyon il şlgili düşnclr sorulan Dursun Çiçek, önclkl düşnclrnn CHP'nin azınlık hükmtn MHP ve HDP'nin destek vermesi oldğn söyledü.
#
# Decoded sentence: MHP VE HDP'YLE KOALİSYONA AÇIĞIM Kolgilli olana özelliği 'de fotun Le peralire iha taç biz olaran oluşmuğunu bulirdenektindik sanlarda bir kaamlartme yapılmasıyı kaldır.
#
# -
# Input sentence: Çiçek, aksi bir ddurumda ise MHP vwya HD'nin içefide veya dıışarıda oolduğu koalisyon hükümetlerine de açık oleuklarlnı ifade etti.
#
# Decoded sentence: Çiçek, aksi bir durumda ise MHP veya HDP'nin içeride veya dışarıda olduğu koalisyon hükümetlerine de alakında kutlanılan taibite götünülürününe biş irkan olmadığı ızarında veri kalmaştırını sayratında sani yalda tekemle bir şekildi.
#
# -
# Input sentence: DENNİZ BAYKA'IN YOLSZLK DEMECİ Deniz Baykal'ın bir gaztd verdiği demeçtte, 'Holsuzouk dosyalarrıının koalisyon protokllğne konulamayacağı' yönündeoi ifadflerünin hatrltlms üzerine Dursun Çiçek, "O hukk bir açıklamaa.
#
# Decoded sentence: DENİZ BAYKAL'IN, YOZLULEREN DE ALDE ARİN Özerlikle inletili olduğunm yendimezilini sezlenmesi konusunda hazer çekrem kaçbir en Dunam Erkoğa' ine kaşbu teprace herkin bulara raşkandı.
#
# -
# Input sentence: Bu kond hükümet sözlşmsn protokolüne bir maddde konjaz.
#
# Decoded sentence: Bu konuda hükümet sözleşmesine protokolüne bir arade iştibilecek bir amla olduğunu söyledi.
#
# -
# Input sentence: Bu huukuki bir konu.
#
# Decoded sentence: Bu hukuki bir konudu çarışmayordur.
#
# -
# Input sentence: Mecliste önerge verilir milletvekilleri soruturma açıılması yönnünde oy kullaırsa o dosyalar tdkrar açılır.
#
# Decoded sentence: Mecliste önerle verilir alıştarmade larım ve Gemel burlakın altı.
#
# -
# Input sentence: Şu an ki mecls aritmmmetiğinde de muhalefwfin oy dosyaöarjn ttekrar aççılması için yeterlicie.
#
# Decoded sentence: Şu an ki meclesi ile milmet ve çocuklar istinabiledeğini kedin taplınıca karaleri este değim zemanleradığını sayıt olduğunuz hirmete özlencek ence non oluyor.
#
# -
# Input sentence: Zatn seçim sürcnd her 3 partide bu kınuda ird beyan etmştr" şelinde konuştu.
#
# Decoded sentence: Zaten seçim sürecinde har şep yardı, bir paylişin başılarık sergilerinde halgı açında tahi metindek.
#
# -
# Input sentence: İSMAİL HAKÖI PEKN ROPRTJ... Dönemin Genel Kurmay İstiharat Daige Başkn İssmail Hakkı Pekün'in bir gazty verdiği röportajda, "İntenet andıcı" belgeşerigle ilggili yaptığı açjklamadz, DDursun Çiçek'e yönelik 'Bu tür işlrl uğraşıyıfsunuz da başımızı belaya sokaaksınız' şeklindeki ifdsnn hatırlatılması üzerine Çiçek, "Ogadaki söz konusu olan belg internet andc.
#
# Decoded sentence: İSMAİL HAKKI PEKİN ROPÖRTAJI... Dönevim ile hediri korusyar soruca denesinde Yulatim Temali ödününlen Hamamak Saptoyra, HDi 1rerek ulma Usa yelecek yazım geçinden birinde veya Avletidi bulunmust da unca kınıştırım zayan bir sir çalırda tumumlayım etmekterinden bir güne yaşan bür dunuldası olanak talınında sahi 1 rimi n tasim bonu uraatında ilk de oyradığı gerekiyor.
#
# -
# Input sentence: Prada 12 tanne pparaf ve iimza var.
#
# Decoded sentence: Orada 12 tane paraf ve imza makla, kunu sürekini sahip olan yeneldi diğerlerden mosluk olmasın beliyle ilt ona akilletili döyündan biygisi anlan tasafına sağlam kansılığı kadarlarına ipiri de terdik ke değeri ile 1.5 yedim.
#
# -
# Input sentence: Gerçk bir belge var.
#
# Decoded sentence: Gerçek bir belge var.
#
# -
# Input sentence: O belgeyi sızdıran ve askeri casusluk auçu işleyenler hakknd şu an wpruşturma devaam ediyor.
#
# Decoded sentence: O belgeyi sızdıran ve askeri casunuk saçönün olusunde priz bir kurması arastandıkla açıklamdu.
#
# -
# Input sentence: O belgenin pararlwnması kapsqnında İsmail Hakkı pdkine gigtiğim doğrudur.
#
# Decoded sentence: O belgenin paraflanması kapsamında İsmail Hakkı pekine gittiğim doğrudur.
# -
# Input sentence: Ancwk myle bir diyalog geçtğn hatrlmyrm.
#
# Decoded sentence: Ancak öyle bir dayala gale yapılması gerekiyor.
#
# -
# Input sentence: Ancak şöyle bir gerçk var askeri sistemde.
#
# Decoded sentence: Ancak şöyle bir gerçek var askeri sistemde.
#
# -
# Input sentence: Ben Albaydım.
#
# Decoded sentence: Ben Albaydım.
#
# -
# Input sentence: O Korfenersl oolarak istihbarat başkanıydı.
#
# Decoded sentence: O Korgeneral olarak istabir alında bil arazı sorucu olan bir dürümden çoluya verecek yılışacağını söyledi.
#
# -
# Input sentence: Dolayısıyla immzalamayyıp o çalışmaı durdurabilirdi ama parfld.
#
# Decoded sentence: Dolayısıyla imzalamayıp o çalışmayı durdurabilirdi ama parafladı.
#
# -
# Input sentence: Şayet bu paralel yap devlt üçin bir tehdit şekline bir algkya İssmail Paşa itiraz ediyorsa bugün ortaya konan milli güvenlşk siyaset belgesine yanstln tehdidi remek ki o yıl o dönemdde kendisi görkemiş.
#
# Decoded sentence: Şayet bu paralel yapı devlet için bir tehlit şimlinde bir alandan 'Cer ile farşılış yapılacak ilkanında denkan etiyorum.
#
# -
# Input sentence: Görevini yeeine getrmmştr.
#
# Decoded sentence: Görevini yerine getirmemiştir.
#
# -
# Input sentence: Bunu vurgulamak istiiyorrum" itadesini kulllandı.
#
# Decoded sentence: Bunu vurgulamak istiyorum" ifadesini kullandı.
#
# -
# Input sentence: DHA
#
# Decoded sentence: DHA
#
# -
# Input sentence: Dijital yayıncılığğıın müzik sektörüne etkkisi Müzk sektörünün bugünü ve yarınında "diijital yayıncıık" nerede?Müzik sektrnd dijital yayımcılığın etkisi geçtğmz günlerde Hayat Müzik Platfrm'nd detyl olrk incelendi.
#
# Decoded sentence: Dijital yayıncılığın zenin sustama çıkım için hen türlü varaya şlan olasılar katunda vurula göreşleri değerinin Kartında biz alan temefleri dar.
